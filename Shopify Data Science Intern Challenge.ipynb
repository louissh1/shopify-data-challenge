# %% [markdown]
# # Question 1

# %% [markdown]
# # Data Exploration

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

from pandas.plotting import scatter_matrix

import matplotlib.pyplot as plt
from pylab import rcParams

# %%
shoes = pd.read_csv('Shopify Data Science Intern Challenge Data Set - Sheet1.csv')

# %%
shoes.head()
# Out:
#    order_id  shop_id  user_id  order_amount  total_items payment_method  \
# 0         1       53      746           224            2           cash
# 1         2       92      925            90            1           cash
# 2         3       44      861           144            1           cash
# 3         4       18      935           156            1    credit_card
# 4         5       18      883           156            1    credit_card
#
#             created_at
# 0  2017-03-13 12:36:56
# 1  2017-03-03 17:38:52
# 2   2017-03-14 4:23:56
# 3  2017-03-26 12:43:37
# 4   2017-03-01 4:35:11

# %%
shoes['order_amount'].describe()
# Out:
# count      5000.000000
# mean       3145.128000
# std       41282.539349
# min          90.000000
# 25%         163.000000
# 50%         284.000000
# 75%         390.000000
# max      704000.000000
# Name: order_amount, dtype: float64

# %%
shoes.boxplot(column='order_amount')

# %%
shoes[shoes['order_amount']==704000.000000]
# Out:
#       order_id  shop_id  user_id  order_amount  total_items payment_method  \
# 15          16       42      607        704000         2000    credit_card
# 60          61       42      607        704000         2000    credit_card
# 520        521       42      607        704000         2000    credit_card
# 1104      1105       42      607        704000         2000    credit_card
# 1362      1363       42      607        704000         2000    credit_card
# 1436      1437       42      607        704000         2000    credit_card
# 1562      1563       42      607        704000         2000    credit_card
# 1602      1603       42      607        704000         2000    credit_card
# 2153      2154       42      607        704000         2000    credit_card
# 2297      2298       42      607        704000         2000    credit_card
# 2835      2836       42      607        704000         2000    credit_card
# ...

# %% [markdown]
# # Q1:

# %% [markdown]
# Q1:
# From the statistics description and boxplot chart above, we could see that there are some outliers in the variable of order amount, which is caused by abnormal big total items amount. We can see that the amount 3145.13 was obtained by taking the average of the order amount column. This amount is large probably because it is the mean, and it is influenced by outliers large and small. We also note that the standard deviation is 41282.54, which is incredibly large, so the values in the data set are further away from the mean. Thus we can see that the mean is not a very good estimate of the AOV.

# %% [markdown]
# # Q2

# %% [markdown]
# A better way to evaluate the data would be to use the median as the AOV. Since it is the middle value of the sorted values, it is a central value but large and small outliers do not skew the median as much as the mean.

# %% [markdown]
# # Q3

# %%
shoes['order_amount'].median()
# Out:
# 284.0

# %% [markdown]
# explore average price per items

# %%
shoes['API']=shoes['order_amount']/shoes['total_items']
shoes['API'].describe()
# Out:
# count     5000.000000
# mean       387.742800
# std       2441.963725
# min         90.000000
# 25%        133.000000
# 50%        153.000000
# 75%        169.000000
# max      25725.000000
# Name: API, dtype: float64

# %%
shoes.boxplot(column='API')

# %%
shoes.head()
# Out:
#    order_id  shop_id  user_id  order_amount  total_items payment_method  \
# 0         1       53      746           224            2           cash
# 1         2       92      925            90            1           cash
# 2         3       44      861           144            1           cash
# 3         4       18      935           156            1    credit_card
# 4         5       18      883           156            1    credit_card
#
#             created_at    AOV
# 0  2017-03-13 12:36:56  112.0
# 1  2017-03-03 17:38:52   90.0
# 2   2017-03-14 4:23:56  144.0
# 3  2017-03-26 12:43:37  156.0
# 4   2017-03-01 4:35:11  156.0

# %%
shoes1=shoes[shoes['API']!=25725.000000]

# %%
shoes1.describe()
# Out:
#           order_id      shop_id      user_id   order_amount  total_items  \
# count  4954.000000  4954.000000  4954.000000    4954.000000  4954.000000
# mean   2498.990916    49.819540   848.919257    2717.367784     8.851029
# std    1444.498907    29.014845    87.846007   41155.996469   116.857286
# min       1.000000     1.000000   607.000000      90.000000     1.000000
# 25%    1248.250000    24.000000   775.000000     163.000000     1.000000
# 50%    2494.500000    50.000000   849.000000     284.000000     2.000000
# 75%    3750.750000    74.000000   925.000000     390.000000     3.000000
# max    5000.000000   100.000000   999.000000  704000.000000  2000.000000
#
#                AOV          API
# count  4954.000000  4954.000000
# mean    152.475575   152.475575
# std      31.260218    31.260218
# min      90.000000    90.000000
# 25%     132.000000   132.000000
# 50%     153.000000   153.000000
# 75%     168.000000   168.000000
# max     352.000000   352.000000

# %% [markdown]
# # Question 2

# %% [markdown]
# Question 2: For this question you’ll need to use SQL. Follow this link to access the data set required for the challenge. Please use queries to answer the following questions. Paste your queries along with your final numerical answers below.
#
# 1. How many orders were shipped by Speedy Express in total?
# Queries:
# SELECT count(OrderID) AS num_orders
# FROM Orders
# JOIN Shippers USING (ShipperID)
# WHERE ShipperName = 'Speedy Express';
#
# Numerical answer:
# 54
#
# 2. What is the last name of the employee with the most orders?
#
# Queries:
# SELECT COUNT(OrderID) AS num_orders, EmployeeID, LastName
#       FROM Orders
#       JOIN Employees USING(EmployeeID)
#       GROUP BY EmployeeID
#       ORDER BY 1 DESC
#       LIMIT 3;
#
# Answer:
# Peacock
#
# 3. What product was ordered the most by customers in Germany?
# Queries:
# Select ProductName, Country, Count(OrderID) as num_orders FROM Customers
# Join Orders USING(CustomerID)
# Join OrderDetails USING(OrderID)
# Join Products USING(ProductID)
# Where Country = 'Germany'
# Group by ProductName
# Order by num_orders Desc;
#
# Answer:
# Gorgonzola Telino
